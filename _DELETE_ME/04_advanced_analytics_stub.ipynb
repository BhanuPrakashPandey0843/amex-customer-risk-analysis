# %% [markdown]
# # 04. Advanced Analytics — American Express CFPB Risk Intelligence
#
# ---
#
# ## Notebook Purpose
# Perform advanced analytics beyond descriptive EDA: segmentation, emerging risk detection, impact quantification, and competitive benchmarking.

# %% [markdown]
# ---
#
# ## 1. Setup & Imports

# %%
import pandas as pd
import numpy as np
from pathlib import Path

project_root = Path.cwd().parent
data_path = project_root / 'data' / 'processed' / 'complaints_cleaned.csv'

df = pd.read_csv(data_path)
df['Date received'] = pd.to_datetime(df['Date received'], utc=True)
print(f"Data loaded: {len(df):,} rows")

# %% [markdown]
# ---
#
# ## Phase 6 in Progress
#
# This notebook will be expanded with advanced analysis: segmentation, emerging risk detection, impact quantification, and competitive benchmarking!
